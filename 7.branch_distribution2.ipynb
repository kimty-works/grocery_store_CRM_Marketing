# %%
# !sudo apt-get install -y fonts-nanum
# !sudo fc-cache -fv
# !rm ~/.cache/matplotlib -rf
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# fonts-nanum is already the newest version (20200506-1).
# 0 upgraded, 0 newly installed, 0 to remove and 38 not upgraded.
# /usr/share/fonts: caching, new cache contents: 0 fonts, 1 dirs
# /usr/share/fonts/truetype: caching, new cache contents: 0 fonts, 3 dirs
# /usr/share/fonts/truetype/humor-sans: caching, new cache contents: 1 fonts, 0 dirs
# /usr/share/fonts/truetype/liberation: caching, new cache contents: 16 fonts, 0 dirs
# /usr/share/fonts/truetype/nanum: caching, new cache contents: 12 fonts, 0 dirs
# /usr/local/share/fonts: caching, new cache contents: 0 fonts, 0 dirs
# /root/.local/share/fonts: skipping, no such directory
# /root/.fonts: skipping, no such directory
# /usr/share/fonts/truetype: skipping, looped directory detected
# /usr/share/fonts/truetype/humor-sans: skipping, looped directory detected
# ...

# %%
import pandas as pd
import numpy as np

# 데이터 시각화
import matplotlib.pyplot as plt
import matplotlib

import seaborn as sns

# %%
plt.rc('font', family='NanumBarunGothic')

# %%
# 실행결과 경고메시지 출력 제외
import warnings

warnings.filterwarnings('ignore')

# %%
# 데이터 구성:Series, DataFrame
import pandas as pd
# 데이터 시각화
import matplotlib.pyplot as plt
import matplotlib

# %% [markdown]
# # 데이터 불러오기

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ## mart A

# %%
martA = pd.read_csv("/content/drive/MyDrive/최강<포빅아A4>/마켓프로젝트/마켓 CSV파일모음/A지점.csv")
martA.head(10)
# Out:
#          공급일자        회원번호 조합원상태 물품대분류  물품중분류   물품소분류                물품명  구매수량  \
# 0  2023-01-06   220954944  정상회원    반찬  두부/유부      두부        두부(1모:420g)   1.0
# 1  2023-01-06    89023040  정상회원    채소   열매채소  단호박/손질     단호박(깍뚝썰기/300g)   1.0
# 2  2023-01-06   354941440  정상회원   축산물      알     유정란   유정란/매장용(10알/국내산)   1.0
# 3  2023-01-06   786634048    탈퇴    반찬   어묵/묵       묵      도토리묵(420g:1모)   1.0
# 4  2023-01-06   438543104  정상회원   축산물      알     유정란   유정란/매장용(10알/국내산)   1.0
# 5  2023-01-06   178387584  정상회원  생활용품    화장품   기초화장품    수피아 기초2종모음/기존용기   1.0
# 6  2023-01-06   735339776  정상회원    채소   양념채소      대파           대파(700g)   1.0
# 7  2023-01-06   673161920  정상회원    간식     과자   한과/유과       약과(200g/18개)   1.0
# 8  2023-01-06   967046528  정상회원    건강  홍삼/녹용      홍삼       홍삼액(6년근/60봉)   1.0
# 9  2023-01-06  1039816576  정상회원  생활용품  식기/편백      편백  편백나무큐브베개(성인/분홍잔꽃)   1.0
#
#      구매금액 구매매장      구매시각 반품일자  구매월  구매일  구매시간대  반품소요기간
# 0    3829  매장A  10:32:00  NaN    1    6     10       0
# ...

# %%
martA.info()

# %% [markdown]
# ## mart B

# %%
martB = pd.read_csv("/content/drive/MyDrive/최강<포빅아A4>/마켓프로젝트/마켓 CSV파일모음/B지점.csv")
martB .head(10)
# Out:
#          공급일자        회원번호 조합원상태  물품대분류    물품중분류     물품소분류  \
# 0  2023-01-06   345017408  정상회원  양념/가루        장     장류/기타
# 1  2023-01-06   395094144  정상회원     간식        빵  식빵, 식사대용
# 2  2023-01-06   735399168  정상회원    축산물        알       유정란
# 3  2023-01-06  1226079168  정상회원     반찬     어묵/묵        어묵
# 4  2023-01-06   748032960  정상회원     채소   잎/줄기채소       시금치
# 5  2023-01-06   837388224  정상회원     간식        빵     앙금크림빵
# 6  2023-01-06   746284608  정상회원     간식        떡       즉석떡
# 7  2023-01-06  1099795072  정상회원  양념/가루  소스/기타양념        소스
# 8  2023-01-06   762804864  정상회원    축산물        알       유정란
# 9  2023-01-06  1540253568  정상회원    축산물      육가공  돈가스/분쇄가공
#
#                    물품명  구매수량   구매금액 구매매장      구매시각 반품일자  구매월  구매일  구매시간대  \
# 0            청국장(150g)   1.0   4786  매장B  10:20:00  NaN    1    6     10
# 1      아침빵(240g/8개)/매장   1.0   4403  매장B  10:38:00  NaN    1    6     10
# 2  동물복지유정란/중란(10알/국내산)   1.0   5552  매장B  10:59:00  NaN    1    6     10
# ...

# %% [markdown]
# ## mart C

# %%
martC = pd.read_csv("/content/drive/MyDrive/최강<포빅아A4>/마켓프로젝트/마켓 CSV파일모음/C지점.csv")
martC .head(10)
# Out:
#          공급일자        회원번호 조합원상태  물품대분류 물품중분류     물품소분류                  물품명  \
# 0  2023-01-06   272369856  정상회원     과실    과일        사과          사과/유(1.5kg)
# 1  2023-01-06  1476143616  정상회원     간식     빵  식빵, 식사대용      아침빵(240g/8개)/매장
# 2  2023-01-06   743192512  정상회원     채소  양념채소        생강             생강(300g)
# 3  2023-01-06   176912064  정상회원    축산물   유제품    우유/산양유  유기농저지방우유(종이팩/900ml)
# 4  2023-01-06    87592064  정상회원  양념/가루    가루      양념가루        카레(매운맛: 100g)
# 5  2023-01-06  1206815744  정상회원     채소  양념채소        대파             대파(700g)
# 6  2023-01-06   740918912  정상회원     채소  열매채소       애호박            쥬키니호박(1개)
# 7  2023-01-06  1343359808  정상회원     채소   콩나물       콩나물            콩나물(300g)
# 8  2023-01-06   246287488  정상회원    축산물     알       유정란     유정란/매장용(10알/국내산)
# 9  2023-01-06   397616448  정상회원     채소  뿌리채소        당근              당근(1kg)
#
#    구매수량   구매금액 구매매장      구매시각 반품일자  구매월  구매일  구매시간대  반품소요기간
# 0   1.0  22207  매장C  10:04:00  NaN    1    6     10       0
# ...

# %% [markdown]
# ## mart D

# %%
martD = pd.read_csv("/content/drive/MyDrive/최강<포빅아A4>/마켓프로젝트/마켓 CSV파일모음/D지점.csv")
martD .head(10)
# Out:
#          공급일자        회원번호 조합원상태  물품대분류   물품중분류     물품소분류               물품명  \
# 0  2023-01-06   133834304  정상회원     잡곡  콩/화본/깨        화본        귀리(무/500g)
# 1  2023-01-06   749556736  정상회원     잡곡  콩/화본/깨        토종       선비콩/유(500g)
# 2  2023-01-06   787320768  정상회원     채소  잎/줄기채소       시금치         시금치(300g)
# 3  2023-01-06   175843008  정상회원     채소    뿌리채소        당근          당근(500g)
# 4  2023-01-06   165261952  정상회원     간식     밀가공        만두         군만두(500g)
# 5  2023-01-06  1486746944  정상회원  양념/가루   기름/식초        기름        현미유(500ml)
# 6  2023-01-06   766076992  정상회원     반찬     밑반찬       김가공        주먹밥채소(36g)
# 7  2023-01-06   389065856  정상회원    축산물       알       유정란  유정란/매장용(10알/국내산)
# 8  2023-01-06   592516864  정상회원     간식       빵  식빵, 식사대용     통밀식빵(300g)/매장
# 9  2023-01-06   161475712  정상회원     간식    식사대용   식사대용/기타         크림스프(80g)
#
#    구매수량   구매금액 구매매장      구매시각 반품일자  구매월  구매일  구매시간대  반품소요기간
# 0   1.0   8232  매장D  10:32:00  NaN    1    6     10       0
# ...

# %%
all=pd.read_csv("/content/drive/MyDrive/최강<포빅아A4>/마켓프로젝트/마켓 CSV파일모음/전체매장데이터.csv")

# %%
all.info()

# %% [markdown]
# ## member

# %%
member = pd.read_csv("/content/drive/MyDrive/최강<포빅아A4>/마켓프로젝트/마켓 CSV파일모음/finmem.csv")
member.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11555 entries, 0 to 11554
# Data columns (total 10 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   회원번호         11555 non-null  int64
#  1   조합원상태        11555 non-null  object
#  2   시            11555 non-null  object
#  3   주소           11555 non-null  object
#  4   성별           11555 non-null  object
#  5   연령           11555 non-null  float64
#  6   연령대          11555 non-null  object
#  7   배송서비스신청여부    11555 non-null  object
#  8   모바일알람여부      11555 non-null  object
#  9   Gold_member  11555 non-null  object
# dtypes: float64(1), int64(1), object(8)
# memory usage: 902.9+ KB

# %%
import pandas as pd

# 모든 mart 데이터프레임을 합침
all_marts = pd.concat([martA, martB, martC, martD])

# member와 모든 mart 데이터프레임을 회원번호를 기준으로 외부 조인
merged_all = pd.merge(member, all_marts, on='회원번호', how='outer')

# 모든 mart에만 존재하고 member에는 없는 회원번호 확인
missing_in_all = merged_all[merged_all['물품대분류'].isnull()]

# 결과 출력
print("모든 Mart에만 존재하고 Member에는 없는 회원번호:")
print(missing_in_all['회원번호'])
# Out:
# 모든 Mart에만 존재하고 Member에는 없는 회원번호:
# Series([], Name: 회원번호, dtype: int64)

# %% [markdown]
# # 지점별 총 구매금액

# %%
# 각 마트의 총 매출액 계산
total_sales = [martA['구매금액'].sum(), martB['구매금액'].sum(), martC['구매금액'].sum(), martD['구매금액'].sum()]
marts = ['Mart A', 'Mart B', 'Mart C', 'Mart D']
total_sales_sum = sum(total_sales)
print(total_sales_sum)
# 그래프 그리기
plt.figure(figsize=(10, 6))
plt.bar(marts, total_sales, color=['blue', 'green', 'orange', 'red'])
plt.title('지점별 총 판매액')
plt.xlabel('Mart')
plt.ylabel('총 판매액(단위: 10억)')
plt.show()
# Out:
# 3255156423

# %%
total_sales

# %% [markdown]
# - Mart C의 매출액이 가장 높다
# - 단위는 10억
# - 데이터 제공 기간인 1/6~11/4일간의 총 판매액임

# %% [markdown]
# # 지점별 월별 판매액

# %% [markdown]
# ### 한번에 추세선으로

# %%
# 지점별 월별 판매액 계산
monthly_sales_A = martA.groupby(['구매월'])['구매금액'].sum()
monthly_sales_B = martB.groupby(['구매월'])['구매금액'].sum()
monthly_sales_C = martC.groupby(['구매월'])['구매금액'].sum()
monthly_sales_D = martD.groupby(['구매월'])['구매금액'].sum()

# 시각화
plt.figure(figsize=(12, 8))

# Mart A
plt.plot(monthly_sales_A.index, monthly_sales_A.values, label='Mart A')
# Mart B
plt.plot(monthly_sales_B.index, monthly_sales_B.values, label='Mart B')
# Mart C
plt.plot(monthly_sales_C.index, monthly_sales_C.values, label='Mart C')
# Mart D
plt.plot(monthly_sales_D.index, monthly_sales_D.values, label='Mart D')

plt.title('지점별 월별 판매액')
plt.xlabel('월')
plt.ylabel('판매액')
plt.legend()
plt.grid(True)
plt.xticks(range(1, 13))
plt.show()

# %% [markdown]
# ### 따로 추세선으로

# %% [markdown]
# 단위아아아악 !!!!!!

# %%
# subplot 생성
fig, axs = plt.subplots(2, 2, figsize=(12, 8))

# Mart A
axs[0, 0].plot(monthly_sales_A.index, monthly_sales_A.values, color='blue')
axs[0, 0].set_title('Mart A')
axs[0, 0].set_xlabel('월')
axs[0, 0].set_ylabel('판매액')
axs[0, 0].grid(True)
axs[0, 0].set_xticks(range(1, 13))

# Mart B
axs[0, 1].plot(monthly_sales_B.index, monthly_sales_B.values, color='green')
axs[0, 1].set_title('Mart B')
axs[0, 1].set_xlabel('월')
axs[0, 1].set_ylabel('판매액')
axs[0, 1].grid(True)
axs[0, 1].set_xticks(range(1, 13))

# Mart C
axs[1, 0].plot(monthly_sales_C.index, monthly_sales_C.values, color='red')
axs[1, 0].set_title('Mart C')
axs[1, 0].set_xlabel('월')
axs[1, 0].set_ylabel('판매액')
axs[1, 0].grid(True)
axs[1, 0].set_xticks(range(1, 13))

# Mart D
axs[1, 1].plot(monthly_sales_D.index, monthly_sales_D.values, color='purple')
axs[1, 1].set_title('Mart D')
axs[1, 1].set_xlabel('월')
axs[1, 1].set_ylabel('판매액')
axs[1, 1].grid(True)
axs[1, 1].set_xticks(range(1, 13))

# subplot 간 간격 조정
plt.tight_layout()

# 그래프 표시
plt.show()

# %% [markdown]
# ### 따로 막대그래프

# %%
import matplotlib.pyplot as plt

# subplot 생성
fig, axs = plt.subplots(2, 2, figsize=(12, 8))

# Mart A
axs[0, 0].bar(monthly_sales_A.index, monthly_sales_A.values, color='blue')
axs[0, 0].set_title('Mart A')
axs[0, 0].set_xlabel('월')
axs[0, 0].set_ylabel('판매액 (단위: 1e7)')
axs[0, 0].grid(True)
axs[0, 0].set_xticks(range(1, 13))

# Mart B
axs[0, 1].bar(monthly_sales_B.index, monthly_sales_B.values, color='green')
axs[0, 1].set_title('Mart B')
axs[0, 1].set_xlabel('월')
axs[0, 1].set_ylabel('판매액 (단위: 1e7)')
axs[0, 1].grid(True)
axs[0, 1].set_xticks(range(1, 13))

# Mart C (단위 변환)
axs[1, 0].bar(monthly_sales_C.index, monthly_sales_C.values / 10, color='red')  # 1e7로 표시하기 위해 10을 나눔
axs[1, 0].set_title('Mart C')
axs[1, 0].set_xlabel('월')
axs[1, 0].set_ylabel('판매액 (단위: 1e7)')
axs[1, 0].grid(True)
axs[1, 0].set_xticks(range(1, 13))

# Mart D
axs[1, 1].bar(monthly_sales_D.index, monthly_sales_D.values, color='purple')
axs[1, 1].set_title('Mart D')
axs[1, 1].set_xlabel('월')
axs[1, 1].set_ylabel('판매액 (단위: 1e7)')
axs[1, 1].grid(True)
axs[1, 1].set_xticks(range(1, 13))

# subplot 간 간격 조정
plt.tight_layout()

# 그래프 표시
plt.show()

# %% [markdown]
# - 모든 지점에서 2월, 7-8월의 구매금액이 높음
# - 마트 C가 다른 지점보다 판매액이 약 2배 가량 높음

# %% [markdown]
# # 지점별 월간 판매량 추이
# - 반품한 물품이라도 계산에 포함함
# - 구매 수량으로 계산함

# %%
# 각 지점에서의 월간 판매량 계산
A_yearly_sales = martA.groupby('구매월')['구매수량'].sum()
B_yearly_sales = martB.groupby('구매월')['구매수량'].sum()
C_yearly_sales = martC.groupby('구매월')['구매수량'].sum()
D_yearly_sales = martD.groupby('구매월')['구매수량'].sum()


# 시각화
plt.figure(figsize=(12, 8))
plt.plot(A_yearly_sales.index, A_yearly_sales.values, label='Mart A')
plt.plot(B_yearly_sales.index, B_yearly_sales.values, label='Mart B')
plt.plot(C_yearly_sales.index, C_yearly_sales.values, label='Mart C')
plt.plot(D_yearly_sales.index, D_yearly_sales.values, label='Mart D')
plt.title('지점별 월간 판매량')
plt.xlabel('월')
plt.ylabel('판매량')
plt.legend()
plt.grid(True)
plt.xticks(range(1, 13))
plt.show()

# %% [markdown]
# - 2023년 1/6 ~ 11/4
# - 전반적으로 3월, 7월에 판매량이 높은 경향을 보임
# - 11월의 판매량이 낮은 이유는 데이터가 11/4 일까지이기 때문
# - 매장 C의 판매량이 다른 매장보다 2배가량 높음

# %% [markdown]
# # 지점별 월간 판매량

# %%
# 시각화
plt.figure(figsize=(12, 8))

plt.subplot(2, 2, 1)
plt.bar(A_yearly_sales.index, A_yearly_sales.values, color='mediumseagreen')
plt.title('Mart A')
plt.xlabel('월')
plt.ylabel('판매량')
plt.xticks(range(1, 13))

plt.subplot(2, 2, 2)
plt.bar(B_yearly_sales.index, B_yearly_sales.values, color='mediumseagreen')
plt.title('Mart B')
plt.xlabel('월')
plt.ylabel('판매량')
plt.xticks(range(1, 13))

plt.subplot(2, 2, 3)
plt.bar(C_yearly_sales.index, C_yearly_sales.values, color='mediumseagreen')
plt.title('Mart C')
plt.xlabel('월')
plt.ylabel('판매량')
plt.xticks(range(1, 13))

plt.subplot(2, 2, 4)
plt.bar(D_yearly_sales.index, D_yearly_sales.values, color='mediumseagreen')
plt.title('Mart D')
plt.xlabel('월')
plt.ylabel('판매량')
plt.xticks(range(1, 13))

plt.tight_layout()
plt.show()

# %% [markdown]
# - mart D를 제외하고 7월에 가장 판매량이 높다
# - mart D는 8월의 판매량이 가장 높다
# - **여름에 판매량이 높은 것을 알 수 있다**

# %% [markdown]
# # 지점별 고객 한 명당 평균 구매액

# %%
# 각 마트에서 고객별 평균 구매금액 계산
A_avg_per_customer = martA.groupby('회원번호')['구매금액'].mean().mean()
B_avg_per_customer = martB.groupby('회원번호')['구매금액'].mean().mean()
C_avg_per_customer = martC.groupby('회원번호')['구매금액'].mean().mean()
D_avg_per_customer = martD.groupby('회원번호')['구매금액'].mean().mean()

# 지점별 고객의 평균 구매금액을 비교하는 그래프 그리기
marts = ['Mart A', 'Mart B', 'Mart C', 'Mart D']
avg_sales = [A_avg_per_customer, B_avg_per_customer, C_avg_per_customer, D_avg_per_customer]

plt.figure(figsize=(10, 6))
plt.bar(marts, avg_sales, color=['blue', 'green', 'orange', 'red'])
plt.title('Average Purchase Amount per Customer by Mart')
plt.xlabel('Mart')
plt.ylabel('Average Purchase Amount')
plt.show()

# %%
avg_sales

# %% [markdown]
# - 한 고객당 구매금액 평균을 구한 후 그 평균값으로 전체 구매고객의 구매금액 평균을 구함
# - 지점별로 고객 한 명당 평균 구매금액은 매점별로 크게 다르지 않음
# - 한 고객의 평균 구매금액이 가장 높은 매점은 mart D

# %% [markdown]
# ## 나중에 고객 등급 나눌 때

# %%
# 개인당 평균 구매금액
# mart A
A_avg_person = martA.groupby('회원번호')['구매금액'].mean().sort_values(ascending=False)

# mart B
B_avg_person = martB.groupby('회원번호')['구매금액'].mean().sort_values(ascending=False)

# mart C
C_avg_person = martC.groupby('회원번호')['구매금액'].mean().sort_values(ascending=False)

# mart D
D_avg_person = martD.groupby('회원번호')['구매금액'].mean().sort_values(ascending=False)

# %%
# 개인당 총 구매금액
# mart A
A_sum_person = martA.groupby('회원번호')['구매금액'].sum().sort_values(ascending=False)

# mart B
B_sum_person = martB.groupby('회원번호')['구매금액'].sum().sort_values(ascending=False)

# mart C
C_sum_person = martC.groupby('회원번호')['구매금액'].sum().sort_values(ascending=False)

# mart D
D_sum_person = martD.groupby('회원번호')['구매금액'].sum().sort_values(ascending=False)

# %% [markdown]
# # 지점별 반품량

# %% [markdown]
# ### 지점 별 반품율

# %% [markdown]
# ## 1년간 지점별 총 반품량 및 반품소요시간의 평균

# %%
import matplotlib.pyplot as plt

# 1. 지점별 반품량 계산
A_returns = martA['반품일자'].notnull().sum()
B_returns = martB['반품일자'].notnull().sum()
C_returns = martC['반품일자'].notnull().sum()
D_returns = martD['반품일자'].notnull().sum()

# 2. 지점별 평균 반품 소요기간 계산
A_avg_return_duration = martA[martA['반품소요기간'] > 0]['반품소요기간'].mean()
B_avg_return_duration = martB[martB['반품소요기간'] > 0]['반품소요기간'].mean()
C_avg_return_duration = martC[martC['반품소요기간'] > 0]['반품소요기간'].mean()
D_avg_return_duration = martD[martD['반품소요기간'] > 0]['반품소요기간'].mean()

# 시각화
marts = ['Mart A', 'Mart B', 'Mart C', 'Mart D']
returns = [A_returns, B_returns, C_returns, D_returns]
avg_durations = [A_avg_return_duration, B_avg_return_duration, C_avg_return_duration, D_avg_return_duration]

fig, ax1 = plt.subplots(figsize=(10, 6))

color = 'mediumseagreen'
ax1.bar(marts, returns, color=color)
ax1.set_ylabel('반품량', color=color)
ax1.tick_params(axis='y', labelcolor=color)

ax2 = ax1.twinx()
color = 'tab:red'
ax2.plot(marts, avg_durations, color=color, marker='o')
ax2.set_ylabel('평균반품소요기간', color=color)
ax2.tick_params(axis='y', labelcolor=color)

fig.tight_layout()
plt.title('지점별 반품량 및 평균반품소요기간')
plt.show()

# %% [markdown]
# - 지점별 반품량은 C지점이 가장 높음
# - 그 다음으로는 D지점이 높았다.
# - 판매량 대비 반품량을 구해보면 좋을 듯
# - 평균 반품 소요기간은 mart D지점이 1.7일로 가장 길었고 mart B가 가장 짧았음
# - 평균 반품 소요기간의 가장 낮고 높은 값의 차이가 약 0.7-0.8차이라 의미가 있을지 ..

# %% [markdown]
# ## 1년간 지점별 판매량 대비 반품량

# %%
import matplotlib.pyplot as plt

# D마트에서 반품한 경우만 선택
returns_D = martD[~martD['반품일자'].isnull()]

# 반품 물품의 물품 소분류별 개수 계산
return_item_counts = returns_D['물품소분류'].value_counts()

# 상위 10개의 물품 소분류 선택
top_10_return_items = return_item_counts.head(10)

# 파이차트 생성
plt.figure(figsize=(10, 8))
top_10_return_items.plot(kind='pie', autopct='%1.1f%%', startangle=140)
plt.title("D마트의 반품 물품 소분류 비율 (Top 10)")
plt.axis('equal')  # 원을 동그랗게 표시
plt.show()

# %%
# 각 지점에서의 총 판매량 계산
A_total_sales = martA['구매수량'].sum()
B_total_sales = martB['구매수량'].sum()
C_total_sales = martC['구매수량'].sum()
D_total_sales = martD['구매수량'].sum()

# 각 지점에서의 총 반품량 계산
A_total_returns = martA['반품일자'].notnull().sum()
B_total_returns = martB['반품일자'].notnull().sum()
C_total_returns = martC['반품일자'].notnull().sum()
D_total_returns = martD['반품일자'].notnull().sum()

# 판매량 대비 반품량 계산
A_returns_ratio = A_total_returns / A_total_sales
B_returns_ratio = B_total_returns / B_total_sales
C_returns_ratio = C_total_returns / C_total_sales
D_returns_ratio = D_total_returns / D_total_sales

# 막대 그래프로 표시
labels = ['Mart A', 'Mart B', 'Mart C', 'Mart D']
ratios = [A_returns_ratio, B_returns_ratio, C_returns_ratio, D_returns_ratio]

plt.figure(figsize=(10, 6))
plt.bar(labels, ratios, color=['skyblue', 'lightgreen', 'salmon', 'gold'])
plt.title('지점별 판매량 대비 반품량')
plt.xlabel('Mart')
plt.ylabel('반품량/판매량')
plt.show()

# %%
ratios

# %% [markdown]
# ** D 마트가 가장 판매량 대비 반품량이 높음 **

# %% [markdown]
# ## A 마트의 월별 반품량

# %%
# A마트에서의 월별 반품량 계산
A_returns_by_month = martA[martA['반품일자'].notnull()].groupby('구매월')['반품일자'].count()

# 시각화
plt.figure(figsize=(10, 6))
A_returns_by_month.plot(kind='bar', color='mediumseagreen')
plt.title('A 마트의 월별 반품량')
plt.xlabel('월')
plt.ylabel('반품량')
plt.ylim(0, 200)
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# - 4월이 반품량이 가장 높다

# %% [markdown]
# ## B 마트의 월별 반품량

# %%
# B마트에서의 월별 반품량 계산
B_returns_by_month = martB[martB['반품일자'].notnull()].groupby('구매월')['반품일자'].count()

# 시각화
plt.figure(figsize=(10, 6))
B_returns_by_month.plot(kind='bar', color='mediumseagreen')
plt.title('B 마트의 월별 반품량')
plt.xlabel('월')
plt.ylabel('반품량')
plt.ylim(0, 200)
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ## C 마트의 월별 반품량

# %%
# C마트에서의 월별 반품량 계산
C_returns_by_month = martC[martC['반품일자'].notnull()].groupby('구매월')['반품일자'].count()

# 시각화
plt.figure(figsize=(10, 6))
C_returns_by_month.plot(kind='bar', color='mediumseagreen')
plt.title('C 마트의 월별 반품량')
plt.xlabel('월')
plt.ylabel('반품량')
plt.ylim(0, 230)
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ## D 마트의 월별 반품량

# %%
# D마트에서의 월별 반품량 계산
D_returns_by_month = martD[martD['반품일자'].notnull()].groupby('구매월')['반품일자'].count()

# 시각화
plt.figure(figsize=(10, 6))
D_returns_by_month.plot(kind='bar', color='mediumseagreen')
plt.title('D 마트의 월별 반품량')
plt.xlabel('월')
plt.ylabel('반품량')
plt.ylim(0, 230)
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# **8월에 유난히 반품량이 많음**

# %%
martA.info()

# %%
# 반품을 한 경우만 선택
import matplotlib.pyplot as plt

def find_most_returned_item(df):
    # 반품을 한 경우만 선택
    returns = df[(df['반품소요기간'] > 0) | (~df['반품일자'].isnull())]

    # 각 물품소분류별로 반품 횟수를 세어줌
    most_returned_item = returns['물품소분류'].value_counts().idxmax()

    return most_returned_item

# 각 마트에서 최다 반품 물품소분류 찾기
most_returned_items = {}
for mart_name, mart_df in [('Mart A', martA), ('Mart B', martB), ('Mart C', martC), ('Mart D', martD)]:
    most_returned_items[mart_name] = find_most_returned_item(mart_df)

print("최다 반품 물품소분류:")
for mart, item in most_returned_items.items():
    print(f"{mart}: {item}")

# %%
import matplotlib.pyplot as plt

# Mart A에서 반품을 한 경우만 선택
returns_martA = martA[(martA['반품소요기간'] > 0) | (~martA['반품일자'].isnull())]

# 각 물품소분류별로 반품 횟수를 세어줌
most_returned_item_martA = returns_martA['물품소분류'].value_counts().idxmax()

# 반품을 가장 많이 한 물품소분류의 파이차트 생성
plt.figure(figsize=(8, 8))
returns_martA['물품소분류'].value_counts().plot.pie(autopct='%1.1f%%', startangle=140, colors=['lightcoral', 'lightskyblue', 'lightgreen', 'lightpink'])

# 제목 설정
plt.title('Mart A의 최다 반품 물품소분류')

# 원을 동그랗게 표시
plt.axis('equal')

# 차트 보이기
plt.show()

# 결과 출력
print("Mart A의 최다 반품 물품소분류:", most_returned_item_martA)

# %%
import matplotlib.pyplot as plt

# Mart A에서 반품을 한 경우만 선택
returns_martA = martA[(martA['반품소요기간'] > 0) | (~martA['반품일자'].isnull())]

# 각 물품소분류별로 반품 횟수를 세어줌
most_returned_items_martA = returns_martA['물품소분류'].value_counts().head(5)

# 반품을 가장 많이 한 상위 5개 물품소분류의 파이차트 생성
plt.figure(figsize=(8, 8))
most_returned_items_martA.plot.pie(autopct='%1.1f%%', startangle=140, colors=['lightcoral', 'lightskyblue', 'lightgreen', 'lightpink','purple'])

# 제목 설정
plt.title('Mart A의 최다 반품 물품소분류 (Top 5)')

# 원을 동그랗게 표시
plt.axis('equal')

# 차트 보이기
plt.show()

# 결과 출력
print("Mart A의 최다 반품 물품소분류 (Top 5):")
print(most_returned_items_martA)

# %%
import matplotlib.pyplot as plt

# Mart A에서 반품을 한 경우만 선택
returns_martA = martA[(martA['반품소요기간'] > 0) | (~martA['반품일자'].isnull())]

# 각 물품소분류별로 반품 횟수를 세어줌
most_returned_items_martA = returns_martA['물품소분류'].value_counts().head(5)

# 반품을 가장 많이 한 상위 5개 물품소분류의 파이차트 생성
plt.figure(figsize=(8, 8))
most_returned_items_martA.plot.pie(autopct='%1.1f%%', startangle=140, colors=['lightcoral', 'lightskyblue', 'lightgreen', 'lightpink','purple'])

# 제목 설정
plt.title('Mart A의 최다 반품 물품소분류 (Top 5)')

# 원을 동그랗게 표시
plt.axis('equal')

# 차트 보이기
plt.show()

# 결과 출력
print("Mart A의 최다 반품 물품소분류 (Top 5):")
print(most_returned_items_martA)


# Mart B에서 반품을 한 경우만 선택
returns_martB = martB[(martB['반품소요기간'] > 0) | (~martB['반품일자'].isnull())]

# 각 물품소분류별로 반품 횟수를 세어줌
most_returned_items_martB = returns_martB['물품소분류'].value_counts().head(5)

# 반품을 가장 많이 한 상위 5개 물품소분류의 파이차트 생성
plt.figure(figsize=(8, 8))
most_returned_items_martB.plot.pie(autopct='%1.1f%%', startangle=140, colors=['lightcoral', 'lightskyblue', 'lightgreen', 'lightpink','purple'])

# 제목 설정
plt.title('Mart B의 최다 반품 물품소분류 (Top 5)')

# 원을 동그랗게 표시
plt.axis('equal')

# 차트 보이기
plt.show()

# 결과 출력
print("Mart B의 최다 반품 물품소분류 (Top 5):")
print(most_returned_items_martB)


# Mart C에서 반품을 한 경우만 선택
returns_martC = martC[(martC['반품소요기간'] > 0) | (~martC['반품일자'].isnull())]

# 각 물품소분류별로 반품 횟수를 세어줌
most_returned_items_martC = returns_martC['물품소분류'].value_counts().head(5)

# 반품을 가장 많이 한 상위 5개 물품소분류의 파이차트 생성
plt.figure(figsize=(8, 8))
most_returned_items_martC.plot.pie(autopct='%1.1f%%', startangle=140, colors=['lightcoral', 'lightskyblue', 'lightgreen', 'lightpink','purple'])

# 제목 설정
plt.title('Mart C의 최다 반품 물품소분류 (Top 5)')

# 원을 동그랗게 표시
plt.axis('equal')

# 차트 보이기
plt.show()

# 결과 출력
print("Mart C의 최다 반품 물품소분류 (Top 5):")
print(most_returned_items_martC)


# Mart D에서 반품을 한 경우만 선택
returns_martD = martD[(martD['반품소요기간'] > 0) | (~martD['반품일자'].isnull())]

# 각 물품소분류별로 반품 횟수를 세어줌
most_returned_items_martD = returns_martD['물품소분류'].value_counts().head(5)

# 반품을 가장 많이 한 상위 5개 물품소분류의 파이차트 생성
plt.figure(figsize=(8, 8))
most_returned_items_martD.plot.pie(autopct='%1.1f%%', startangle=140, colors=['lightcoral', 'lightskyblue', 'lightgreen', 'lightpink','purple'])

# 제목 설정
plt.title('Mart D의 최다 반품 물품소분류 (Top 5)')

# 원을 동그랗게 표시
plt.axis('equal')

# 차트 보이기
plt.show()

# 결과 출력
print("Mart D의 최다 반품 물품소분류 (Top 5):")
print(most_returned_items_martD)

# %% [markdown]
# # 지점별 회원수

# %% [markdown]
# 기간은 데이터 제공일인 1월~11월으로 한다.

# %%
# 각 지점에서의 고유 회원 수 계산
A_unique_customers = martA['회원번호'].nunique()
B_unique_customers = martB['회원번호'].nunique()
C_unique_customers = martC['회원번호'].nunique()
D_unique_customers = martD['회원번호'].nunique()

print("Mart A Unique Customers:", A_unique_customers)
print("Mart B Unique Customers:", B_unique_customers)
print("Mart C Unique Customers:", C_unique_customers)
print("Mart D Unique Customers:", D_unique_customers)

# 각 지점에서의 고유 회원 수 계산
unique_customers = [A_unique_customers, B_unique_customers, C_unique_customers, D_unique_customers]
marts = ['Mart A', 'Mart B', 'Mart C', 'Mart D']

# 시각화
plt.figure(figsize=(10, 6))
plt.bar(marts, unique_customers, color='mediumseagreen')
plt.title('지점별 구매 회원 수')
plt.xlabel('Mart')
plt.ylabel('기간 내 구매 회원 수')
plt.show()

# %% [markdown]
# - mart C가 기간 내 구매한 회원의 수가 가장 높음

# %% [markdown]
# # 지점별 이탈율

# %% [markdown]
# <의논할 내용>
# - 해당 데이터는 탈퇴 회원이 구매했을 때 기록이 된 것임
# - 실제 탈퇴 시기는 알 수 없음
# - 탈퇴하거나 애초에 조합원에 가입하지 않은 고객이 구매했을 때 기록이 된 것이기 때문에 이탈율을 구하기 어려움
# - 이 데이터는 **물품을 구매했지만 조합원이 아닌 회원의 수**임 -> 이게 뭘 의미하는지 모르겠음 ..
# - + 구매 기록이 찍힐 당시의 조합원 상태를 나타낸 거겠지? > yes

# %% [markdown]
# ## mart A

# %%
# mart A
# 마트 A에서 월별 탈퇴 회원 수 계산
A_churn_by_month = martA[martA['조합원상태'] == '탈퇴'].groupby('구매월')['회원번호'].nunique()

# 시각화
plt.figure(figsize=(10, 6))
plt.bar(A_churn_by_month.index, A_churn_by_month.values, color='mediumseagreen')
plt.title("Mart A의 월별 탈퇴 회원 수")
plt.xlabel('월')
plt.ylabel('탈퇴한 회원 구매 고객 수')
plt.ylim(0,40)
plt.xticks(range(1, 13))
plt.grid(True)
plt.show()

# %% [markdown]
# martA 데이터프레임에서 '조합원상태'가 '탈퇴'인 행을 필터링합니다. 이는 마트 A에서 탈퇴한 회원들의 데이터를 선택하는 것입니다.\
# 선택된 데이터를 '구매월' 열을 기준으로 그룹화합니다. 이렇게 하면 각 월별로 탈퇴한 회원들의 데이터가 그룹으로 묶이게 됩니다.\
# 각 그룹에 대해 '회원번호'의 고유한 값의 개수를 계산합니다. 이는 각 월별로 탈퇴한 회원들의 수를 나타냅니다.

# %% [markdown]
# ## mart B

# %%
# mart B
# 마트 B에서 월별 탈퇴 회원 수 계산
B_churn_by_month = martB[martB['조합원상태'] == '탈퇴'].groupby('구매월')['회원번호'].nunique()

# 시각화
plt.figure(figsize=(10, 6))
plt.bar(B_churn_by_month.index, B_churn_by_month.values, color='mediumseagreen')
plt.title("Mart B의 월별 탈퇴 회원 수")
plt.xlabel('월')
plt.ylabel('탈퇴한 회원 구매 고객 수')
plt.ylim(0,40)
plt.xticks(range(1, 13))
plt.grid(True)
plt.show()

# %% [markdown]
# ## mart C

# %%
# mart C
# 마트 C에서 월별 탈퇴 회원 수 계산
C_churn_by_month = martC[martC['조합원상태'] == '탈퇴'].groupby('구매월')['회원번호'].nunique()

# 시각화
plt.figure(figsize=(10, 6))
plt.bar(C_churn_by_month.index, C_churn_by_month.values, color='mediumseagreen')
plt.title("Mart C의 월별 탈퇴 회원 수")
plt.xlabel('월')
plt.ylabel('탈퇴한 회원 구매 고객 수')
plt.ylim(0,40)
plt.xticks(range(1, 13))
plt.grid(True)
plt.show()

# %% [markdown]
# ## mart D

# %%
# mart D
# 마트 D에서 월별 탈퇴 회원 수 계산
D_churn_by_month = martD[martD['조합원상태'] == '탈퇴'].groupby('구매월')['회원번호'].nunique()

# 시각화
plt.figure(figsize=(10, 6))
plt.bar(D_churn_by_month.index, D_churn_by_month.values, color='mediumseagreen')
plt.title("Mart C의 월별 탈퇴 회원 수")
plt.xlabel('월')
plt.ylabel('탈퇴한 회원 구매 고객 수')
plt.ylim(0,40)
plt.xticks(range(1, 13))
plt.grid(True)
plt.show()

# %% [markdown]
# - 조합원이 아닌 회원이 구매하는 월이 연 초에 많고 점점 줄어듦

# %% [markdown]
# # 지점별 주거지 비율(파이차트)

# %% [markdown]
# ### member 데이터프레임 merge

# %%
# member merge
# martA와 member 데이터프레임을 '회원번호'를 기준으로 조인하기
martA_with_address = pd.merge(martA, member[['회원번호', '시', '주소','연령대']], on='회원번호', how='left')

# 조인된 데이터프레임 확인하기
martA_with_address.head()

# %%
martA_with_address.info()

# %%
# mart B, C, D에 대해서도 진행
martB_with_address = pd.merge(martB, member[['회원번호', '시', '주소','연령대']], on='회원번호', how='left')
martC_with_address = pd.merge(martC, member[['회원번호', '시', '주소','연령대']], on='회원번호', how='left')
martD_with_address = pd.merge(martD, member[['회원번호', '시', '주소','연령대']], on='회원번호', how='left')

# %%
mart_with_address = pd.merge(mart, member[['회원번호', '시', '주소','연령대']], on='회원번호', how='left')

# %%
member.info()

# %%
# martA와 member 데이터프레임을 '회원번호'를 기준으로 조인하기
martA_merge = pd.merge(martA, member[['회원번호', '시', '주소','연령','연령대']], on='회원번호', how='left')

# %% [markdown]
# ### 지점 별 이용 고객 연령대

# %%
# 회원번호와 구매매장을 기준으로 중복 제거
unique_customers = martA_with_address.drop_duplicates(subset=['회원번호', '구매매장'])

# 유니크한 고객의 연령대와 구매매장별로 그룹화하여 카운트
age_dist = unique_customers.groupby(['구매매장', '연령대']).size().reset_index(name='고객 수')

plt.figure(figsize=(8, 4))
sns.countplot(data=martA_with_address, x='연령대', hue='구매매장', color='mediumseagreen')
plt.title('지점별 고객 연령대 분포')
plt.xlabel('연령대')
plt.ylabel('고객 수')
plt.legend(title='구매매장')
plt.xticks(rotation=45)
plt.show()

# %%
unique_customers.nunique()

# %%
age_dist

# %%
# 회원번호와 구매매장을 기준으로 중복 제거
unique_customers = martB_with_address.drop_duplicates(subset=['회원번호', '구매매장'])

# 유니크한 고객의 연령대와 구매매장별로 그룹화하여 카운트
age_dist = unique_customers.groupby(['구매매장', '연령대']).size().reset_index(name='고객 수')

plt.figure(figsize=(10, 6))
sns.countplot(data=martA_with_address, x='연령대', hue='구매매장', color='mediumseagreen')
plt.title('지점별 고객 연령대 분포')
plt.xlabel('연령대')
plt.ylabel('고객 수')
plt.legend(title='구매매장')
plt.xticks(rotation=45)
plt.show()

# %%
unique_customers.nunique()

# %%
age_dist

# %%
# 회원번호와 구매매장을 기준으로 중복 제거
unique_customers = martC_with_address.drop_duplicates(subset=['회원번호', '구매매장'])

# 유니크한 고객의 연령대와 구매매장별로 그룹화하여 카운트
age_dist = unique_customers.groupby(['구매매장', '연령대']).size().reset_index(name='고객 수')

plt.figure(figsize=(8, 4))
sns.countplot(data=martA_with_address, x='연령대', hue='구매매장', color='mediumseagreen')
plt.title('지점별 고객 연령대 분포')
plt.xlabel('연령대')
plt.ylabel('고객 수')
plt.legend(title='구매매장')
plt.xticks(rotation=45)
plt.show()

# %%
age_dist

# %%
# 회원번호와 구매매장을 기준으로 중복 제거
unique_customers = martD_with_address.drop_duplicates(subset=['회원번호', '구매매장'])

# 유니크한 고객의 연령대와 구매매장별로 그룹화하여 카운트
age_dist = unique_customers.groupby(['구매매장', '연령대']).size().reset_index(name='고객 수')

plt.figure(figsize=(8, 4))
sns.countplot(data=martA_with_address, x='연령대', hue='구매매장', color='mediumseagreen')
plt.title('지점별 고객 연령대 분포')
plt.xlabel('연령대')
plt.ylabel('고객 수')
plt.legend(title='구매매장')
plt.xticks(rotation=45)
plt.show()

# %%
age_dist

# %%
martA_with_address.head(1)

# %% [markdown]
# ### 지점 별 구매 고객 연령대

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# 각 데이터프레임에 대한 리스트 생성
mart_data = [martA_with_address, martB_with_address, martC_with_address, martD_with_address]
mart_names = ['A', 'B', 'C', 'D']  # 각 지점의 이름

fig, axes = plt.subplots(2, 2, figsize=(20, 12))  # 2x2 subplot 생성
axes = axes.flatten()  # 2D 축 배열을 1D로 변환

for i, mart in enumerate(mart_data):
    sns.countplot(data=mart, x='연령대', ax=axes[i], color='mediumseagreen')
    axes[i].set_title(f'{mart_names[i]} 지점 고객 연령대 분포')
    axes[i].set_xlabel('연령대')
    axes[i].set_ylabel('고객 수')
    axes[i].tick_params(axis='x', rotation=45)

plt.tight_layout()  # 그래프 간 충돌을 방지하기 위해 자동으로 레이아웃을 조정
plt.show()

# %%
# 가정: 'df'는 데이터프레임의 이름이며, 모든 구매 데이터를 포함하고 있다.

# 회원번호와 구매매장을 기준으로 중복 제거
unique_customers = martA_with_address.drop_duplicates(subset=['회원번호', '구매매장'])

# 유니크한 고객의 연령대와 구매매장별로 그룹화하여 카운트
age_dist = unique_customers.groupby(['구매매장', '연령대']).size().reset_index(name='고객 수')

# 시각화를 위해 '구매매장'별로 데이터 분할
fig, axes = plt.subplots(2, 2, figsize=(15, 10), sharey=True)
axes = axes.flatten()

# 각 매장별로 막대그래프 그리기
for i, store in enumerate(unique_customers['구매매장'].unique()):
    store_data = age_dist[age_dist['구매매장'] == store]
    sns.barplot(data=store_data, x='연령대', y='고객 수', ax=axes[i], color='mediumseagreen')
    axes[i].set_title(f'{store} 지점 고객 연령대 분포')
    axes[i].set_xlabel('연령대')
    axes[i].set_ylabel('고객 수')
    axes[i].tick_params(axis='x', rotation=45)

plt.tight_layout()
plt.show()

# %%
martA.info()

# %% [markdown]
# ## mart A

# %% [markdown]
# - 글자가 너무 겹치고 비율이 적어 광주, 하남, 화성시를 인근경기지역으로 묶음

# %%
martA_with_address.info()

# %%
martB_with_address.head()

# %% [markdown]
# ### 회원의 거주 시 비율

# %%
# mart A의 주거지 비율
# '광주', '하남', '화성'을 '인근경기지역'으로 치환
martA_with_address['시'] = martA_with_address['시'].replace({'광주': '인근경기지역', '하남': '인근경기지역', '화성': '인근경기지역'})

# 시별 회원 수 계산
city_counts = martA_with_address['시'].value_counts()

# 색상 설정
colors = ['mediumseagreen', 'lightgreen', 'lightcyan', 'lightblue']

# 파이차트 그리기
plt.figure(figsize=(8, 8))
plt.pie(city_counts, labels=city_counts.index, autopct='%1.1f%%', startangle=140, colors=colors)
plt.title("A의 지역별 회원 수 비율")
plt.axis('equal')  # 원형으로 표현
plt.tight_layout()  # 글자 겹침 방지
plt.show()

# %% [markdown]
# ### 용인의 구 비율 확인
# - 가장 많은 비율을 차지하는 용인시의 동 비율을 확인

# %%
# '시'가 용인인 데이터만 필터링
yongin_data = martA_with_address[martA_with_address['시'] == '용인']

# '주소' 열에서 구, 동 정보 추출
yongin_data['구'] = yongin_data['주소'].str.split('-', expand=True)[0]
yongin_data['동'] = yongin_data['주소'].str.split('-', expand=True)[1]

# 각 구의 비율 계산
district_counts = yongin_data['구'].value_counts(normalize=True) * 100


# 색상 설정
colors = ['mediumseagreen', 'lightgreen', 'lightcyan', 'lightblue']

# 파이차트 그리기
plt.figure(figsize=(8, 8))
plt.pie(district_counts, labels=district_counts.index, autopct='%1.1f%%', startangle=140, colors=colors)
plt.title("용인시의 구별 회원 수 비율")
plt.axis('equal')  # 원형으로 표현
plt.tight_layout()  # 글자 겹침 방지
plt.show()

# %% [markdown]
# ### 수지구의 동 비율 확인

# %%
# 수지구의 동별 비율 계산
suji_district_counts = yongin_data[yongin_data['구'] == '수지구']['동'].value_counts(normalize=True) * 100

# 색상 설정
colors = ['mediumseagreen', 'lightgreen', 'lightcyan', 'lightblue']

# 파이차트 그리기
plt.figure(figsize=(8, 8))
plt.pie(suji_district_counts, labels=suji_district_counts.index, autopct='%1.1f%%', startangle=140, colors=colors)
plt.title("용인시 수지구의 동별 회원 수 비율")
plt.axis('equal')  # 원형으로 표현
plt.tight_layout()  # 글자 겹침 방지
plt.show()

# %% [markdown]
# ## mart B

# %% [markdown]
# ### 회원의 거주시 비율

# %%
# mart B의 주거지 비율
# '광주', '하남', '화성'을 '인근경기지역'으로 치환
martB_with_address['시'] = martB_with_address['시'].replace({'광주': '인근경기지역', '하남': '인근경기지역', '화성': '인근경기지역'})

# 시별 회원 수 계산
city_counts = martB_with_address['시'].value_counts()

# 색상 설정
colors = ['mediumseagreen', 'lightgreen', 'lightcyan', 'lightblue']

# 파이차트 그리기
plt.figure(figsize=(8, 8))
plt.pie(city_counts, labels=city_counts.index, autopct='%1.1f%%', startangle=140, colors=colors)
plt.title("지역별 회원 수 비율")
plt.axis('equal')  # 원형으로 표현
plt.tight_layout()  # 글자 겹침 방지
plt.show()

# %% [markdown]
# ### 용인시 거주 회원의 구 비율 확인

# %%
# '시'가 용인인 데이터만 필터링
yongin_data_B = martB_with_address[martB_with_address['시'] == '용인']

# '주소' 열에서 구 정보 추출
yongin_data_B['구'] = yongin_data_B['주소'].str.split('-', expand=True)[0]
yongin_data_B['동'] = yongin_data_B['주소'].str.split('-', expand=True)[1]

# 각 구의 비율 계산
district_counts = yongin_data_B['구'].value_counts(normalize=True) * 100


# 색상 설정
colors = ['mediumseagreen', 'lightgreen', 'lightcyan', 'lightblue']

# 파이차트 그리기
plt.figure(figsize=(8, 8))
plt.pie(district_counts, labels=district_counts.index, autopct='%1.1f%%', startangle=140, colors=colors)
plt.title("용인시의 구별 회원 수 비율")
plt.axis('equal')  # 원형으로 표현
plt.tight_layout()  # 글자 겹침 방지
plt.show()

# %% [markdown]
# ### 수지구 거주 회원의 동 비율 확인

# %%
import matplotlib.pyplot as plt

# 수지구의 동별 비율 계산
suji_district_counts = yongin_data_B[yongin_data_B['구'] == '수지구']['동'].value_counts(normalize=True) * 100


# 색상 설정
colors = ['mediumseagreen', 'lightgreen', 'lightcyan', 'lightblue']

# 파이차트 그리기
plt.figure(figsize=(8, 8))
plt.pie(suji_district_counts, labels=suji_district_counts.index, autopct='%1.1f%%', startangle=140, colors=colors)
plt.title("B 마트 용인시 수지구의 동별 회원 수 비율")
plt.axis('equal')  # 원형으로 표현
plt.tight_layout()  # 글자 겹침 방지
plt.show()

# %% [markdown]
# ## mart C

# %% [markdown]
# ### 회원의 거주시 비율

# %%
# mart C의 주거지 비율
# '광주', '하남', '화성'을 '인근경기지역'으로 치환
martC_with_address['시'] = martC_with_address['시'].replace({'광주': '인근경기지역', '하남': '인근경기지역', '화성': '인근경기지역'})

# 시별 회원 수 계산
city_counts = martC_with_address['시'].value_counts()

# 색상 설정
colors = ['mediumseagreen', 'lightgreen', 'lightcyan', 'lightblue']

# 파이차트 그리기
plt.figure(figsize=(8, 8))
plt.pie(city_counts, labels=city_counts.index, autopct='%1.1f%%', startangle=140, colors=colors)
plt.title("지역별 회원 수 비율")
plt.axis('equal')  # 원형으로 표현
plt.tight_layout()  # 글자 겹침 방지
plt.show()

# %% [markdown]
# ### 용인시 거주 회원의 구 비율

# %%
# '시'가 용인인 데이터만 필터링
yongin_data_C = martC_with_address[martC_with_address['시'] == '용인']

# '주소' 열에서 구 정보 추출
yongin_data_C['구'] = yongin_data_C['주소'].str.split('-', expand=True)[0]
yongin_data_C['동'] = yongin_data_C['주소'].str.split('-', expand=True)[1]

# 각 구의 비율 계산
district_counts = yongin_data_C['구'].value_counts(normalize=True) * 100


# 색상 설정
colors = ['mediumseagreen', 'lightgreen', 'lightcyan', 'lightblue']

# 파이차트 그리기
plt.figure(figsize=(8, 8))
plt.pie(district_counts, labels=district_counts.index, autopct='%1.1f%%', startangle=140, colors=colors)
plt.title("용인시의 구별 회원 수 비율")
plt.axis('equal')  # 원형으로 표현
plt.tight_layout()  # 글자 겹침 방지
plt.show()

# %% [markdown]
# ### 수지구 거주 회원의 동 비율

# %%
import matplotlib.pyplot as plt

# 수지구의 동별 비율 계산
suji_district_counts = yongin_data_C[yongin_data_C['구'] == '수지구']['동'].value_counts(normalize=True) * 100


# 색상 설정
colors = ['mediumseagreen', 'lightgreen', 'lightcyan', 'lightblue']

# 파이차트 그리기
plt.figure(figsize=(8, 8))
plt.pie(suji_district_counts, labels=suji_district_counts.index, autopct='%1.1f%%', startangle=140, colors=colors)
plt.title("C 마트 용인시 수지구의 동별 회원 수 비율")
plt.axis('equal')  # 원형으로 표현
plt.tight_layout()  # 글자 겹침 방지
plt.show()

# %% [markdown]
# ## mart D

# %% [markdown]
# ### 회원의 거주시 비율

# %%
# mart D의 주거지 비율
# '광주', '하남', '화성'을 '인근경기지역'으로 치환
martD_with_address['시'] = martD_with_address['시'].replace({'광주': '인근경기지역', '하남': '인근경기지역', '화성': '인근경기지역'})

# 시별 회원 수 계산
city_counts = martD_with_address['시'].value_counts()

# 색상 설정
colors = ['mediumseagreen', 'lightgreen', 'lightcyan', 'lightblue']

# 파이차트 그리기
plt.figure(figsize=(8, 8))
plt.pie(city_counts, labels=city_counts.index, autopct='%1.1f%%', startangle=140, colors=colors)
plt.title("지역별 회원 수 비율")
plt.axis('equal')  # 원형으로 표현
plt.tight_layout()  # 글자 겹침 방지
plt.show()

# %% [markdown]
# ### 용인시 거주 회원의 구 비율

# %%
# '시'가 용인인 데이터만 필터링
yongin_data_D = martD_with_address[martD_with_address['시'] == '용인']

# '주소' 열에서 구 정보 추출
yongin_data_D['구'] = yongin_data_D['주소'].str.split('-', expand=True)[0]
yongin_data_D['동'] = yongin_data_D['주소'].str.split('-', expand=True)[1]

# 각 구의 비율 계산
district_counts = yongin_data_D['구'].value_counts(normalize=True) * 100


# 색상 설정
colors = ['mediumseagreen', 'lightgreen', 'lightcyan', 'lightblue']

# 파이차트 그리기
plt.figure(figsize=(8, 8))
plt.pie(district_counts, labels=district_counts.index, autopct='%1.1f%%', startangle=140, colors=colors)
plt.title("용인시의 구별 회원 수 비율")
plt.axis('equal')  # 원형으로 표현
plt.tight_layout()  # 글자 겹침 방지
plt.show()

# %% [markdown]
# ### 수지구 거주 회원의 동 비율

# %%
# 수지구의 동별 비율 계산
suji_district_counts = yongin_data_D[yongin_data_D['구'] == '수지구']['동'].value_counts(normalize=True) * 100


# 색상 설정
colors = ['mediumseagreen', 'lightgreen', 'lightcyan', 'lightblue']

# 파이차트 그리기
plt.figure(figsize=(8, 8))
plt.pie(suji_district_counts, labels=suji_district_counts.index, autopct='%1.1f%%', startangle=140, colors=colors)
plt.title("D 마트 용인시 수지구의 동별 회원 수 비율")
plt.axis('equal')  # 원형으로 표현
plt.tight_layout()  # 글자 겹침 방지
plt.show()

# %% [markdown]
# # 연령대 별 평균 소비금액

# %% [markdown]
# ### 지점 별 평균 이용 연령대

# %% [markdown]
# ## 하루 평균

# %%
import matplotlib.pyplot as plt

# 연령대별 평균 구매금액 계산
average_purchase_by_age = combined_data.groupby('연령대')['구매금액'].mean()

# 막대 그래프 생성
plt.figure(figsize=(6, 4))  # 크기 조정
average_purchase_by_age.plot(kind='bar', color='mediumseagreen')

# 막대에 수치 표시
for i, v in enumerate(average_purchase_by_age):
    plt.text(i, v + 10, f'{v:,.0f}', ha='center', va='bottom')

# 그래프 제목 및 축 레이블 설정
plt.title('연령대별 하루 평균 구매금액')
plt.xlabel('연령대')
plt.ylabel('평균 구매금액')

# 그래프 출력
plt.tight_layout()
plt.show()

# %%
# 구매월을 기준으로 데이터를 그룹화하여 각 그룹 내에서 연령대 별로 합계를 계산합니다.
total_purchase_by_month_age = combined_data.groupby(['구매월', '연령대'])['구매금액'].sum().reset_index()

# 각 연령대별로 해당 달의 평균 구매금액을 계산합니다.
average_purchase_by_month_age = total_purchase_by_month_age.groupby('연령대').apply(lambda x: x.groupby('구매월')['구매금액'].mean()).reset_index()

# 결과 출력
print(average_purchase_by_month_age)

# %% [markdown]
# ## 연령대별 월 별 평균 구매금액

# %%
import matplotlib.pyplot as plt

# 막대 그래프 생성
plt.figure(figsize=(10,6))

# 각 연령대별로 막대 그래프를 생성합니다.
for age_group in average_purchase_by_month_age['연령대'].unique():
    data = average_purchase_by_month_age[(average_purchase_by_month_age['연령대'] == age_group) & (average_purchase_by_month_age['구매월'] != 11)]
    plt.bar(data['구매월'], data['구매금액'], label=f'연령대 {age_group}')

# 그래프 제목 및 축 레이블 설정
plt.title('연령대별 월별 평균 구매금액')
plt.xlabel('구매월')
plt.ylabel('평균 구매금액')

# 범례 추가
plt.legend()

# 색상 설정
plt.gca().set_prop_cycle(None) # 색상 초기화
colors = ['mediumseagreen'] * len(average_purchase_by_month_age['연령대'].unique())
plt.gca

# 그래프 출력
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 연령대별 한 달간 평균 구매금액

# %%
# 연령대별로 1월부터 10월까지의 총 구매금액 계산
total_purchase_by_age = combined_data.groupby('연령대')['구매금액'].sum()

# 연령대별로 1월부터 10월까지의 총 구매금액을 10으로 나누어 월평균 구매금액 계산
monthly_average_purchase_by_age = total_purchase_by_age / 10

# 연령대 순서 변경 (20대 이하부터 시작)
monthly_average_purchase_by_age = monthly_average_purchase_by_age.reindex(index=['20대 이하', '20대', '30대', '40대', '50대', '60대', '70대', '80대', '90대', '100대 이상'])

# 막대 그래프 생성
plt.figure(figsize=(10, 6))
plt.bar(monthly_average_purchase_by_age.index, monthly_average_purchase_by_age.values, color='mediumseagreen')

# 막대에 수치 표시
for i, v in enumerate(monthly_average_purchase_by_age.values):
    plt.text(i, v + 100000, f'{v:,.0f}', ha='center', va='bottom')

# 그래프 제목 및 축 레이블 설정
plt.title('연령대별 한 달간 평균 구매금액')
plt.xlabel('연령대')
plt.ylabel('평균 구매금액')

# 그래프 출력
plt.tight_layout()
plt.show()

# %% [markdown]
# # 지점별 인기 상품

# %%
# 매점별 가장 많이 판매되는 상품 추출 후 내림차순 정렬
top_items_A = martA['물품대분류'].value_counts().nlargest(5).sort_values()
top_items_B = martB['물품대분류'].value_counts().nlargest(5).sort_values()
top_items_C = martC['물품대분류'].value_counts().nlargest(5).sort_values()
top_items_D = martD['물품대분류'].value_counts().nlargest(5).sort_values()

# 막대 차트 그리기
plt.figure(figsize=(12, 8))

plt.subplot(2, 2, 1)
top_items_A.plot(kind='barh', color='skyblue')
plt.title('Mart A Top 5 Popular Items')
plt.xlabel('Number of Sales')
plt.ylabel('Item Category')

plt.subplot(2, 2, 2)
top_items_B.plot(kind='barh', color='lightgreen')
plt.title('Mart B Top 5 Popular Items')
plt.xlabel('Number of Sales')
plt.ylabel('Item Category')

plt.subplot(2, 2, 3)
top_items_C.plot(kind='barh', color='salmon')
plt.title('Mart C Top 5 Popular Items')
plt.xlabel('Number of Sales')
plt.ylabel('Item Category')

plt.subplot(2, 2, 4)
top_items_D.plot(kind='barh', color='gold')
plt.title('Mart D Top 5 Popular Items')
plt.xlabel('Number of Sales')
plt.ylabel('Item Category')

plt.tight_layout()
plt.show()

# %%
top_items_A

# %% [markdown]
# # 요일별 방문자 수

# %%
all

# %%
# '공급일자' 열을 datetime 형식으로 변환하여 '요일' 열 추가
all['공급일자'] = pd.to_datetime(all['공급일자'])
all['요일'] = all['공급일자'].dt.day_name()
all

# %%
import plotly.express as px

# %%
all['방문수'] = 1
p1  = all.pivot_table(index=['회원번호','공급일자'],values='방문수',aggfunc='min').reset_index()
p2 = p1.pivot_table(index='회원번호',values='방문수',aggfunc='sum').reset_index()

# %%
all_visited = pd.merge(all.drop(columns='방문수'), p2, on='회원번호', how='left')
p3 = all_visited.pivot_table(index=['요일','구매매장'],values='방문수',aggfunc='sum').reset_index()

# %%
px.bar(p3, x='요일', y='방문수',color='구매매장')

# %%
# 요일별로 잘 팔리는 품목의 Top 5 구하기
top_items_by_weekday = all.groupby(['요일', '물품명']).size().reset_index(name='판매수량')
top_items_by_weekday = top_items_by_weekday.sort_values(by=['요일', '판매수량'], ascending=[True, False])
top_items_by_weekday = top_items_by_weekday.groupby('요일').head(5)

# 시각화
import plotly.express as px

fig = px.bar(top_items_by_weekday, x='요일', y='판매수량', color='물품명', title='요일별 Top 5 판매 품목')
fig.show()

# %%
# 요일별로 잘 팔리는 품목의 Top 5 구하기
top_items_by_weekday = all.groupby(['요일', '물품소분류']).size().reset_index(name='판매수량')
top_items_by_weekday = top_items_by_weekday.sort_values(by=['요일', '판매수량'], ascending=[True, False])
top_items_by_weekday = top_items_by_weekday.groupby('요일').head(5)

# 시각화
import plotly.express as px

fig = px.bar(top_items_by_weekday, x='요일', y='판매수량', color='물품소분류', title='요일별 Top 5 판매 품목')
fig.show()

# %% [markdown]
# # 지점별 구매 시간대

# %% [markdown]
# ### 각 지점별 구매가 가장 높은 시간대

# %%
import matplotlib.pyplot as plt

# 각 지점에서 가장 높은 빈도를 가지는 구매 시간대 추출
most_common_purchase_time_A = martA['구매시간대'].mode()[0]
most_common_purchase_time_B = martB['구매시간대'].mode()[0]
most_common_purchase_time_C = martC['구매시간대'].mode()[0]
most_common_purchase_time_D = martD['구매시간대'].mode()[0]

# 시간대 빈도를 히스토그램으로 시각화
plt.figure(figsize=(12, 8))

plt.subplot(2, 2, 1)
plt.hist(martA['구매시간대'], bins=24, color='skyblue')
plt.axvline(most_common_purchase_time_A, color='red', linestyle='dashed', linewidth=1)
plt.title('Mart A Purchase Time Distribution')
plt.xlabel('Hour of the Day')
plt.ylabel('Frequency')

plt.subplot(2, 2, 2)
plt.hist(martB['구매시간대'], bins=24, color='lightgreen')
plt.axvline(most_common_purchase_time_B, color='red', linestyle='dashed', linewidth=1)
plt.title('Mart B Purchase Time Distribution')
plt.xlabel('Hour of the Day')
plt.ylabel('Frequency')

plt.subplot(2, 2, 3)
plt.hist(martC['구매시간대'], bins=24, color='salmon')
plt.axvline(most_common_purchase_time_C, color='red', linestyle='dashed', linewidth=1)
plt.title('Mart C Purchase Time Distribution')
plt.xlabel('Hour of the Day')
plt.ylabel('Frequency')

plt.subplot(2, 2, 4)
plt.hist(martD['구매시간대'], bins=24, color='gold')
plt.axvline(most_common_purchase_time_D, color='red', linestyle='dashed', linewidth=1)
plt.title('Mart D Purchase Time Distribution')
plt.xlabel('Hour of the Day')
plt.ylabel('Frequency')

plt.tight_layout()
plt.show()

# %%
most_common_purchase_time_A
# Out:
# 16

# %%
import matplotlib.pyplot as plt

# 각 매장에서 가장 높은 빈도를 가지는 구매 시간대 추출
most_common_purchase_time_A = martA['구매시간대'].mode()[0]
most_common_purchase_time_B = martB['구매시간대'].mode()[0]
most_common_purchase_time_C = martC['구매시간대'].mode()[0]
most_common_purchase_time_D = martD['구매시간대'].mode()[0]

# 각 매장에서 가장 높은 구매 시간대에 가장 많이 판매되는 상품 추출 후 내림차순 정렬
top_items_at_most_common_time_A = martA[martA['구매시간대'] == most_common_purchase_time_A]['물품대분류'].value_counts().nlargest(5).sort_values()
top_items_at_most_common_time_B = martB[martB['구매시간대'] == most_common_purchase_time_B]['물품대분류'].value_counts().nlargest(5).sort_values()
top_items_at_most_common_time_C = martC[martC['구매시간대'] == most_common_purchase_time_C]['물품대분류'].value_counts().nlargest(5).sort_values()
top_items_at_most_common_time_D = martD[martD['구매시간대'] == most_common_purchase_time_D]['물품대분류'].value_counts().nlargest(5).sort_values()


# 시각화
plt.figure(figsize=(12, 8))

plt.subplot(2, 2, 1)
top_items_at_most_common_time_A.plot(kind='barh', color='skyblue')
plt.title('Mart A - Most Popular Items at Peak Time')
plt.xlabel('Item Category')
plt.ylabel('Number of Sales')

plt.subplot(2, 2, 2)
top_items_at_most_common_time_B.plot(kind='barh', color='lightgreen')
plt.title('Mart B - Most Popular Items at Peak Time')
plt.xlabel('Item Category')
plt.ylabel('Number of Sales')

plt.subplot(2, 2, 3)
top_items_at_most_common_time_C.plot(kind='barh', color='salmon')
plt.title('Mart C - Most Popular Items at Peak Time')
plt.xlabel('Item Category')
plt.ylabel('Number of Sales')

plt.subplot(2, 2, 4)
top_items_at_most_common_time_D.plot(kind='barh', color='gold')
plt.title('Mart D - Most Popular Items at Peak Time')
plt.xlabel('Item Category')
plt.ylabel('Number of Sales')

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

# 각 매장에서 가장 높은 빈도를 가지는 구매 시간대 추출
most_common_purchase_time_A = martA['구매시간대'].mode()[0]
most_common_purchase_time_B = martB['구매시간대'].mode()[0]
most_common_purchase_time_C = martC['구매시간대'].mode()[0]
most_common_purchase_time_D = martD['구매시간대'].mode()[0]

# 각 매장에서 가장 높은 구매 시간대에 가장 많이 판매되는 상품 추출 후 내림차순 정렬
top_items_at_most_common_time_A = martA[martA['구매시간대'] == most_common_purchase_time_A]['물품소분류'].value_counts().nlargest(5).sort_values()
top_items_at_most_common_time_B = martB[martB['구매시간대'] == most_common_purchase_time_B]['물품소분류'].value_counts().nlargest(5).sort_values()
top_items_at_most_common_time_C = martC[martC['구매시간대'] == most_common_purchase_time_C]['물품소분류'].value_counts().nlargest(5).sort_values()
top_items_at_most_common_time_D = martD[martD['구매시간대'] == most_common_purchase_time_D]['물품소분류'].value_counts().nlargest(5).sort_values()


# 시각화
plt.figure(figsize=(12, 8))

plt.subplot(2, 2, 1)
top_items_at_most_common_time_A.plot(kind='barh', color='skyblue')
plt.title('Mart A - Most Popular Items at Peak Time')
plt.xlabel('Item Category')
plt.ylabel('Number of Sales')

plt.subplot(2, 2, 2)
top_items_at_most_common_time_B.plot(kind='barh', color='lightgreen')
plt.title('Mart B - Most Popular Items at Peak Time')
plt.xlabel('Item Category')
plt.ylabel('Number of Sales')

plt.subplot(2, 2, 3)
top_items_at_most_common_time_C.plot(kind='barh', color='salmon')
plt.title('Mart C - Most Popular Items at Peak Time')
plt.xlabel('Item Category')
plt.ylabel('Number of Sales')

plt.subplot(2, 2, 4)
top_items_at_most_common_time_D.plot(kind='barh', color='gold')
plt.title('Mart D - Most Popular Items at Peak Time')
plt.xlabel('Item Category')
plt.ylabel('Number of Sales')

plt.tight_layout()
plt.show()

# %% [markdown]
# # 매출 비율이 가장 높은 상품

# %%
# 각 품목별 매출 계산
item_sales = martA.groupby('물품소분류')['구매금액'].sum()

# 전체 매출 계산
total_sales = martA['구매금액'].sum()

# 각 품목별 매출 비율 계산
item_sales_ratio = (item_sales / total_sales) * 100

# 매출 비율이 높은 순서로 정렬
sorted_item_sales_ratio = item_sales_ratio.sort_values(ascending=False)

# 상위 5개 품목 선택
top_5_items = sorted_item_sales_ratio.head(5)

# 결과 출력
print("매출 비율이 가장 높은 상위 5개 품목:")
print(top_5_items.round(3))

# %%
# 각 품목별 매출 계산 (Mart B)
item_sales_b = martB.groupby('물품소분류')['구매금액'].sum()

# 각 품목별 매출 계산 (Mart C)
item_sales_c = martC.groupby('물품소분류')['구매금액'].sum()

# 각 품목별 매출 계산 (Mart D)
item_sales_d = martD.groupby('물품소분류')['구매금액'].sum()

# 전체 매출 계산 (Mart B)
total_sales_b = martB['구매금액'].sum()

# 전체 매출 계산 (Mart C)
total_sales_c = martC['구매금액'].sum()

# 전체 매출 계산 (Mart D)
total_sales_d = martD['구매금액'].sum()

# 각 품목별 매출 비율 계산 (Mart B)
item_sales_ratio_b = (item_sales_b / total_sales_b) * 100

# 각 품목별 매출 비율 계산 (Mart C)
item_sales_ratio_c = (item_sales_c / total_sales_c) * 100

# 각 품목별 매출 비율 계산 (Mart D)
item_sales_ratio_d = (item_sales_d / total_sales_d) * 100

# 매출 비율이 높은 순서로 정렬 (Mart B)
sorted_item_sales_ratio_b = item_sales_ratio_b.sort_values(ascending=False)

# 매출 비율이 높은 순서로 정렬 (Mart C)
sorted_item_sales_ratio_c = item_sales_ratio_c.sort_values(ascending=False)

# 매출 비율이 높은 순서로 정렬 (Mart D)
sorted_item_sales_ratio_d = item_sales_ratio_d.sort_values(ascending=False)

# 상위 5개 품목 선택 (Mart B)
top_5_items_b = sorted_item_sales_ratio_b.head(5)

# 상위 5개 품목 선택 (Mart C)
top_5_items_c = sorted_item_sales_ratio_c.head(5)

# 상위 5개 품목 선택 (Mart D)
top_5_items_d = sorted_item_sales_ratio_d.head(5)

# 결과 출력 (Mart A)
print("Mart A의 매출 비율이 가장 높은 상위 5개 품목:")
print(top_5_items.round(3))

# 결과 출력 (Mart B)
print("Mart B의 매출 비율이 가장 높은 상위 5개 품목:")
print(top_5_items_b.round(3))

# 결과 출력 (Mart C)
print("Mart C의 매출 비율이 가장 높은 상위 5개 품목:")
print(top_5_items_c.round(3))

# 결과 출력 (Mart D)
print("Mart D의 매출 비율이 가장 높은 상위 5개 품목:")
print(top_5_items_d.round(3))

# %%
import matplotlib.pyplot as plt

# 막대 그래프 생성 (Mart A)
plt.figure(figsize=(10, 6))
plt.bar(top_5_items.index, top_5_items.values, color='skyblue')
plt.title('Mart A의 매출 비율이 가장 높은 상위 5개 품목')
plt.xlabel('물품소분류')
plt.ylabel('매출 비율 (%)')
plt.ylim(0,5.5)
plt.xticks(rotation=45)
plt.show()

# 막대 그래프 생성 (Mart B)
plt.figure(figsize=(10, 6))
plt.bar(top_5_items_b.index, top_5_items_b.values, color='lightgreen')
plt.title('Mart B의 매출 비율이 가장 높은 상위 5개 품목')
plt.xlabel('물품소분류')
plt.ylabel('매출 비율 (%)')
plt.ylim(0,5.5)
plt.xticks(rotation=45)
plt.show()

# 막대 그래프 생성 (Mart C)
plt.figure(figsize=(10, 6))
plt.bar(top_5_items_c.index, top_5_items_c.values, color='lightcoral')
plt.title('Mart C의 매출 비율이 가장 높은 상위 5개 품목')
plt.xlabel('물품소분류')
plt.ylabel('매출 비율 (%)')
plt.ylim(0,5.5)
plt.xticks(rotation=45)
plt.show()

# 막대 그래프 생성 (Mart D)
plt.figure(figsize=(10, 6))
plt.bar(top_5_items_d.index, top_5_items_d.values, color='lightskyblue')
plt.title('Mart D의 매출 비율이 가장 높은 상위 5개 품목')
plt.xlabel('물품소분류')
plt.ylabel('매출 비율 (%)')
plt.ylim(0,5.5)
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# # 특정 상품 매출 비율

# %% [markdown]
# ## 두부

# %%
# '두부' 상품에 대한 매출 계산
tofu_sales = martA[martA['물품소분류'] == '두부']['구매금액'].sum()

# 전체 상품의 매출 계산
total_sales = martA['구매금액'].sum()

# '두부' 상품의 매출 비율 계산
tofu_sales_ratio = (tofu_sales / total_sales) * 100

# 결과 출력
print("'두부' 상품의 매출: {}원".format(tofu_sales))
print("전체 상품의 매출: {}원".format(total_sales))
print("'두부' 상품의 매출 비율: {:.2f}%".format(tofu_sales_ratio))

# %% [markdown]
# ## 유정란

# %%
# '두부' 상품에 대한 매출 계산
tofu_sales = martA[martA['물품소분류'] == '유정란']['구매금액'].sum()

# 전체 상품의 매출 계산
total_sales = martA['구매금액'].sum()

# '두부' 상품의 매출 비율 계산
tofu_sales_ratio = (tofu_sales / total_sales) * 100

# 결과 출력
print("'유정란' 상품의 매출: {}원".format(tofu_sales))
print("전체 상품의 매출: {}원".format(total_sales))
print("'유정란' 상품의 매출 비율: {:.2f}%".format(tofu_sales_ratio))

# %% [markdown]
# ## 홍삼액

# %%
# '두부' 상품에 대한 매출 계산
tofu_sales = martA[martA['물품소분류'] == '홍삼']['구매금액'].sum()

# 전체 상품의 매출 계산
total_sales = martA['구매금액'].sum()

# '두부' 상품의 매출 비율 계산
tofu_sales_ratio = (tofu_sales / total_sales) * 100

# 결과 출력
print("'홍삼' 상품의 매출: {}원".format(tofu_sales))
print("전체 상품의 매출: {}원".format(total_sales))
print("'홍삼' 상품의 매출 비율: {:.2f}%".format(tofu_sales_ratio))

# %% [markdown]
# # 지점 별 특성 분석에서 더 파보기

# %% [markdown]
# ## D지점 파기

# %%
martD_with_address.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-20-59e40a80966e> in <cell line: 1>()
# ----> 1 martD_with_address.head()
#
# NameError: name 'martD_with_address' is not defined

# %%
martD.info()

# %%
martD_with_address.info()

# %% [markdown]
# ## D지점 60대분석

# %%
martD_with_address['연령대'].unique()

# %%
# 60대 고객의 데이터 필터링
D_60s = martD_with_address[martD_with_address['연령대'] == '60대']

# 상위 구매 품목 계산
top_items_60s = D_60s['물품명'].value_counts().head(10)

# 결과 출력
print(top_items_60s)

# %%
# DataFrame으로 변환
top_items_df = pd.DataFrame(list(top_items_60s.items()), columns=['물품명', '구매 횟수'])

# 막대그래프 그리기
plt.figure(figsize=(10, 6))
sns.barplot(data=top_items_df, x='구매 횟수', y='물품명', palette='viridis')
plt.title('D지점 60대 고객의 상위 구매 품목')
plt.xlabel('구매 횟수')
plt.ylabel('물품명')
plt.show()

# %% [markdown]
# ### D지점 고가 제품 있는지

# %%
# 구매 금액이 30,000원 이상인 거래 필터링
high_value_purchases = martD_with_address[martD_with_address['구매금액'] >= 30000]

# 필터링된 데이터에서 '물품명'과 '구매금액'을 선택하여 상위 10개 출력
top_high_value_purchases = high_value_purchases[['물품명', '구매금액']].sort_values(by='구매금액', ascending=False).head(10)
print(top_high_value_purchases)

# %% [markdown]
# ## 매출 공신 아이템 : 매주!!

# %%
# '물품명'이 '메주(1말:약6-7kg:솔뫼)'인 데이터 필터링
filtered_data = martD_with_address[martD_with_address['물품명'] == '메주(1말:약6-7kg:솔뫼)']

# 필터링된 데이터 조회
filtered_data.sort_values(by='구매금액',ascending=False)

# %%
# '물품명'이 '메주(1말:약6-7kg:솔뫼)'인 데이터 필터링
filtered_data = martC_with_address[martC_with_address['물품명'] == '메주(1말:약6-7kg:솔뫼)']

# 필터링된 데이터 조회
filtered_data.sort_values(by='구매금액',ascending=False)

# %%
# '물품명'이 '메주(1말:약6-7kg:솔뫼)'인 데이터 필터링
filtered_data = martA_with_address[martA_with_address['물품명'] == '메주(1말:약6-7kg:솔뫼)']

# 필터링된 데이터 조회
filtered_data.sort_values(by='구매금액',ascending=False)

# %%
# '물품명'이 '메주(1말:약6-7kg:솔뫼)'인 데이터 필터링
filtered_data = martB_with_address[martB_with_address['물품명'] == '메주(1말:약6-7kg:솔뫼)']

# 필터링된 데이터 조회
filtered_data.sort_values(by='구매금액',ascending=False)

# %% [markdown]
# ### D지점 연령대 별 상위 구매 품목

# %%
# 필요한 라이브러리 불러오기
import pandas as pd

# 데이터 준비 (예시로 martD_with_address 사용)
# martD_with_address = pd.read_csv('your_data.csv')  # 데이터 파일 로드 예시

# 연령대 별 상위 구매 품목 조회 함수 정의
def top_items_by_age_group(martD_with_address, n_top=5):
    # 연령대 별로 그룹화
    grouped = martD_with_address.groupby(['연령대', '물품명'])

    # 각 그룹 내에서 구매수량 합계 계산
    purchase_counts = grouped['구매수량'].sum().reset_index(name='총 구매수량')

    # 연령대와 구매수량 기준으로 정렬
    sorted_purchases = purchase_counts.sort_values(['연령대', '총 구매수량'], ascending=[True, False])

    # 각 연령대 별 상위 n_top개 품목 추출
    top_items = sorted_purchases.groupby('연령대').head(n_top)

    return top_items

# 함수 실행하여 결과 확인
top_items = top_items_by_age_group(martD_with_address, n_top=5)
print(top_items)

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# 데이터 준비: 'top_items'를 사용
# top_items = top_items_by_age_group(martD_with_address, n_top=5)

# 연령대별로 데이터 분할 및 각각의 막대그래프 그리기
unique_ages = top_items['연령대'].unique()  # 고유한 연령대 추출

# 막대그래프를 그리기 위한 설정
sns.set(style="whitegrid")
plt.figure(figsize=(10, 6 * len(unique_ages)))

for i, age in enumerate(unique_ages, start=1):
    plt.subplot(len(unique_ages), 1, i)  # 각 연령대별로 subplot 생성
    age_data = top_items[top_items['연령대'] == age]
    sns.barplot(x='총 구매수량', y='물품명', data=age_data, palette='viridis')
    plt.title(f'{age} 상위 구매 품목')
    plt.xlabel('총 구매수량')
    plt.ylabel('')

plt.tight_layout()
plt.show()

# %% [markdown]
# # A점 오후 10시, 4시 핫 제품 /고객 연령대 분석

# %%
martA_with_address.info()

# %%
martA_with_address['구매시간대'].unique()

# %%
martA_merge.info()

# %%
import pandas as pd

# 구매시간대가 14, 15, 16, 17인 데이터 필터링
filtered_data = martA_merge[martA_merge['구매시간대'].isin([14, 15, 16, 17])]

# 필터링된 데이터에서 '구매시간대' 별 평균 연령 계산
average_age_by_time = filtered_data.groupby('구매시간대')['연령'].mean()

print("각 구매시간대별 평균 연령:")
print(average_age_by_time)

# %%
import pandas as pd

# '회원번호'와 '구매시각'을 기준으로 중복 제거하여 고유 방문만 추출
unique_visits = martA_with_address.drop_duplicates(subset=['회원번호', '구매시각'])

# 시간대별 방문 횟수 계산
visits_by_time = unique_visits['구매시간대'].value_counts().sort_index()

# 시간대별 방문 횟수 분포 시각화
import matplotlib.pyplot as plt

plt.figure(figsize=(12, 6))
visits_by_time.plot(kind='bar', color='skyblue')
plt.title('Visit Frequency by Time of Day')
plt.xlabel('Hour of Day')
plt.ylabel('Number of Visits')
plt.xticks(rotation=45)
plt.grid(axis='y', linestyle='--')
plt.show()

# %%
visits_by_time

# %%
# '회원번호'와 '구매시각'을 기준으로 중복 제거하여 고유 방문만 추출
unique_visits = martB_with_address.drop_duplicates(subset=['회원번호', '구매시각'])

# 시간대별 방문 횟수 계산
visits_by_time = unique_visits['구매시간대'].value_counts().sort_index()

# 시간대별 방문 횟수 분포 시각화
import matplotlib.pyplot as plt

plt.figure(figsize=(12, 6))
visits_by_time.plot(kind='bar', color='skyblue')
plt.title('Visit Frequency by Time of Day')
plt.xlabel('Hour of Day')
plt.ylabel('Number of Visits')
plt.xticks(rotation=45)
plt.grid(axis='y', linestyle='--')
plt.show()

# %%
visits_by_time

# %%
# '회원번호'와 '구매시각'을 기준으로 중복 제거하여 고유 방문만 추출
unique_visits = martC_with_address.drop_duplicates(subset=['회원번호', '구매시각'])

# 시간대별 방문 횟수 계산
visits_by_time = unique_visits['구매시간대'].value_counts().sort_index()

# 시간대별 방문 횟수 분포 시각화
import matplotlib.pyplot as plt

plt.figure(figsize=(12, 6))
visits_by_time.plot(kind='bar', color='skyblue')
plt.title('Visit Frequency by Time of Day')
plt.xlabel('Hour of Day')
plt.ylabel('Number of Visits')
plt.xticks(rotation=45)
plt.grid(axis='y', linestyle='--')
plt.show()

# %%
visits_by_time

# %%
# '회원번호'와 '구매시각'을 기준으로 중복 제거하여 고유 방문만 추출
unique_visits = martD_with_address.drop_duplicates(subset=['회원번호', '구매시각'])

# 시간대별 방문 횟수 계산
visits_by_time = unique_visits['구매시간대'].value_counts().sort_index()

# 시간대별 방문 횟수 분포 시각화
import matplotlib.pyplot as plt

plt.figure(figsize=(12, 6))
visits_by_time.plot(kind='bar', color='skyblue')
plt.title('Visit Frequency by Time of Day')
plt.xlabel('Hour of Day')
plt.ylabel('Number of Visits')
plt.xticks(rotation=45)
plt.grid(axis='y', linestyle='--')
plt.show()

# %%
visits_by_time
